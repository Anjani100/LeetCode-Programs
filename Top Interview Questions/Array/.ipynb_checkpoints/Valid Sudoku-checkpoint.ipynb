# %%
board = [
  ["8","3",".",".","7",".",".",".","."],
  ["6",".",".","1","9","5",".",".","."],
  [".","9","8",".",".",".",".","6","."],
  ["8",".",".",".","6",".",".",".","3"],
  ["4",".",".","8",".","3",".",".","1"],
  ["7",".",".",".","2",".",".",".","6"],
  [".","6",".",".",".",".","2","8","."],
  [".",".",".","4","1","9",".",".","5"],
  [".",".",".",".","8",".",".","7","9"]
]

for i in range(len(board)):
    for j in range(len(board[i])):
        k = j + 1
        while(k < len(board[i])):
            print(i, j, k, board[i][j], board[i][k], board[j][i], board[k][i])
            if(board[i][j] == board[i][k] and board[i][j] != '.'):
                print('False')
            elif(board[j][i] == board[k][i] and board[j][i] != '.'):
                print('False')
            k += 1
# Out:
# 0 0 1 8 3 8 6
# 0 0 2 8 . 8 .
# 0 0 3 8 . 8 8
# False
# 0 0 4 8 7 8 4
# 0 0 5 8 . 8 7
# 0 0 6 8 . 8 .
# 0 0 7 8 . 8 .
# 0 0 8 8 . 8 .
# 0 1 2 3 . 6 .
# 0 1 3 3 . 6 8
# 0 1 4 3 7 6 4
# 0 1 5 3 . 6 7
# 0 1 6 3 . 6 .
# 0 1 7 3 . 6 .
# 0 1 8 3 . 6 .
# 0 2 3 . . . 8
# 0 2 4 . 7 . 4
# 0 2 5 . . . 7
# 0 2 6 . . . .
# 0 2 7 . . . .
# 0 2 8 . . . .
# 0 3 4 . 7 8 4
# 0 3 5 . . 8 7
# 0 3 6 . . 8 .
# 0 3 7 . . 8 .
# 0 3 8 . . 8 .
# 0 4 5 7 . 4 7
# 0 4 6 7 . 4 .
# 0 4 7 7 . 4 .
# 0 4 8 7 . 4 .
# 0 5 6 . . 7 .
# 0 5 7 . . 7 .
# 0 5 8 . . 7 .
# 0 6 7 . . . .
# 0 6 8 . . . .
# 0 7 8 . . . .
# 1 0 1 6 . 3 .
# 1 0 2 6 . 3 9
# 1 0 3 6 1 3 .
# 1 0 4 6 9 3 .
# 1 0 5 6 5 3 .
# 1 0 6 6 . 3 6
# 1 0 7 6 . 3 .
# 1 0 8 6 . 3 .
# 1 1 2 . . . 9
# 1 1 3 . 1 . .
# 1 1 4 . 9 . .
# 1 1 5 . 5 . .
# 1 1 6 . . . 6
# 1 1 7 . . . .
# 1 1 8 . . . .
# 1 2 3 . 1 9 .
# 1 2 4 . 9 9 .
# 1 2 5 . 5 9 .
# 1 2 6 . . 9 6
# 1 2 7 . . 9 .
# 1 2 8 . . 9 .
# 1 3 4 1 9 . .
# 1 3 5 1 5 . .
# 1 3 6 1 . . 6
# 1 3 7 1 . . .
# 1 3 8 1 . . .
# ...

# %%
import collections
board = [
  ["8","3",".",".","7",".",".",".","."],
  ["6",".",".","1","9","5",".",".","."],
  [".","9","8",".",".",".",".","6","."],
  ["8",".",".",".","6",".",".",".","3"],
  ["4",".",".","8",".","3",".",".","1"],
  ["7",".",".",".","2",".",".",".","6"],
  [".","6",".",".",".",".","2","8","."],
  [".",".",".","4","1","9",".",".","5"],
  [".",".",".",".","8",".",".","7","9"]
]

for i in board:
    s = collections.Counter(i)
    print(s)
for i in range(len(board)):
    a = []
    for j in range(len(board[i])):
        a.append(board[j][i])
    s = collections.Counter(a)
    print(s)
for i in range(len(board)):
    for j in range(len(board[i])):
        if(i % 3 == 1):
            if((board[i][j] == board[i + 1][j + 1]) or (board[i][j] == board[i + ]):
# Out:
# Counter({'.': 6, '8': 1, '3': 1, '7': 1})
# Counter({'.': 5, '6': 1, '1': 1, '9': 1, '5': 1})
# Counter({'.': 6, '9': 1, '8': 1, '6': 1})
# Counter({'.': 6, '8': 1, '6': 1, '3': 1})
# Counter({'.': 5, '4': 1, '8': 1, '3': 1, '1': 1})
# Counter({'.': 6, '7': 1, '2': 1, '6': 1})
# Counter({'.': 6, '6': 1, '2': 1, '8': 1})
# Counter({'.': 5, '4': 1, '1': 1, '9': 1, '5': 1})
# Counter({'.': 6, '8': 1, '7': 1, '9': 1})
# Counter({'.': 4, '8': 2, '6': 1, '4': 1, '7': 1})
# Counter({'.': 6, '3': 1, '9': 1, '6': 1})
# Counter({'.': 8, '8': 1})
# Counter({'.': 6, '1': 1, '8': 1, '4': 1})
# Counter({'.': 3, '7': 1, '9': 1, '6': 1, '2': 1, '1': 1, '8': 1})
# Counter({'.': 6, '5': 1, '3': 1, '9': 1})
# Counter({'.': 8, '2': 1})
# Counter({'.': 6, '6': 1, '8': 1, '7': 1})
# Counter({'.': 4, '3': 1, '1': 1, '6': 1, '5': 1, '9': 1})
